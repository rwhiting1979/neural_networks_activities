# %% [markdown]
# # Fitting and Testing a Neural Network
#
# **Note:** The first three sections of this notebook are the same steps followed on the previous demos.

# %%
# Initial imports
import pandas as pd
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Keras modules
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## Data Generation and Preprocessing

# %%
# Generate 1000 demo data samples with 2 features and two centers
X, y = make_blobs(n_samples=1000, centers=2, n_features=2, random_state=1)

# %%
# Transforming y to a vertical vector
y = y.reshape(-1, 1)
y.shape
# Out:
# (1000, 1)

# %%
# Creating a DataFrame with the dummy data
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"] = y
df.head()
# Out:
#    Feature 1  Feature 2  Target
# 0  -3.058373   4.488258       0
# 1  -8.609739  -3.727149       1
# 2   1.371297   5.231074       0
# 3  -9.339176  -2.954447       1
# 4 -11.571786  -3.852755       1

# %%
# Plotting the dummy data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
# Out:
# <AxesSubplot:xlabel='Feature 1', ylabel='Feature 2'>

# %%
# Create training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create scaler instance
X_scaler = StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Creating a Neural Network Model

# %%
# Create a sequential neural network model
neuron = Sequential()

# %%
# Add the input and the hidden layer to the model
number_inputs = 2
number_hidden_nodes = 3

neuron.add(Dense(units=number_hidden_nodes, activation="relu", input_dim=number_inputs))

# %%
# Add the output layer
number_classes = 1

neuron.add(Dense(units=number_classes, activation="sigmoid"))

# %%
# Display model summary
neuron.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 3)                 9
#
#  dense_1 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compiling a Neural Network Model

# %%
# Create a sequential neural network model
neuron.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# ## Fitting and Testing a Neural Network

# %%
# Fitting the model
model = neuron.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 0s 977us/step - loss: 0.6568 - accuracy: 0.5667
# Epoch 2/100
# 24/24 [==============================] - 0s 927us/step - loss: 0.6227 - accuracy: 0.6600
# Epoch 3/100
# 24/24 [==============================] - 0s 926us/step - loss: 0.5886 - accuracy: 0.7560
# Epoch 4/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5534 - accuracy: 0.8453
# Epoch 5/100
# 24/24 [==============================] - 0s 903us/step - loss: 0.5176 - accuracy: 0.9053
# Epoch 6/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4821 - accuracy: 0.9507
# Epoch 7/100
# 24/24 [==============================] - 0s 925us/step - loss: 0.4475 - accuracy: 0.9827
# Epoch 8/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4143 - accuracy: 0.9907
# Epoch 9/100
# 24/24 [==============================] - 0s 915us/step - loss: 0.3826 - accuracy: 0.9933
# Epoch 10/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3530 - accuracy: 0.9960
# Epoch 11/100
# 24/24 [==============================] - 0s 964us/step - loss: 0.3252 - accuracy: 0.9973
# Epoch 12/100
# 24/24 [==============================] - 0s 975us/step - loss: 0.2991 - accuracy: 0.9987
# Epoch 13/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2750 - accuracy: 0.9987
# Epoch 14/100
# 24/24 [==============================] - 0s 934us/step - loss: 0.2527 - accuracy: 1.0000
# Epoch 15/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2324 - accuracy: 1.0000
# Epoch 16/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2135 - accuracy: 1.0000
# Epoch 17/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1963 - accuracy: 1.0000
# Epoch 18/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1807 - accuracy: 1.0000
# Epoch 19/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1664 - accuracy: 1.0000
# Epoch 20/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1534 - accuracy: 1.0000
# Epoch 21/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1415 - accuracy: 1.0000
# Epoch 22/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1307 - accuracy: 1.0000
# Epoch 23/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1209 - accuracy: 1.0000
# Epoch 24/100
# 24/24 [==============================] - 0s 940us/step - loss: 0.1120 - accuracy: 1.0000
# Epoch 25/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1039 - accuracy: 1.0000
# Epoch 26/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0965 - accuracy: 1.0000
# Epoch 27/100
# 24/24 [==============================] - 0s 955us/step - loss: 0.0897 - accuracy: 1.0000
# Epoch 28/100
# 24/24 [==============================] - 0s 982us/step - loss: 0.0836 - accuracy: 1.0000
# Epoch 29/100
# 24/24 [==============================] - 0s 972us/step - loss: 0.0780 - accuracy: 1.0000
# Epoch 30/100
# 24/24 [==============================] - 0s 957us/step - loss: 0.0729 - accuracy: 1.0000
# Epoch 31/100
# 24/24 [==============================] - 0s 886us/step - loss: 0.0682 - accuracy: 1.0000
# Epoch 32/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0638 - accuracy: 1.0000
# Epoch 33/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0599 - accuracy: 1.0000
# Epoch 34/100
# 24/24 [==============================] - 0s 903us/step - loss: 0.0563 - accuracy: 1.0000
# Epoch 35/100
# 24/24 [==============================] - 0s 881us/step - loss: 0.0529 - accuracy: 1.0000
# Epoch 36/100
# 24/24 [==============================] - 0s 970us/step - loss: 0.0498 - accuracy: 1.0000
# Epoch 37/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0470 - accuracy: 1.0000
# Epoch 38/100
# 24/24 [==============================] - 0s 891us/step - loss: 0.0444 - accuracy: 1.0000
# Epoch 39/100
# 24/24 [==============================] - 0s 893us/step - loss: 0.0419 - accuracy: 1.0000
# Epoch 40/100
# 24/24 [==============================] - 0s 928us/step - loss: 0.0397 - accuracy: 1.0000
# Epoch 41/100
# 24/24 [==============================] - 0s 923us/step - loss: 0.0376 - accuracy: 1.0000
# Epoch 42/100
# 24/24 [==============================] - 0s 962us/step - loss: 0.0356 - accuracy: 1.0000
# Epoch 43/100
# 24/24 [==============================] - 0s 964us/step - loss: 0.0338 - accuracy: 1.0000
# Epoch 44/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 45/100
# 24/24 [==============================] - 0s 937us/step - loss: 0.0306 - accuracy: 1.0000
# Epoch 46/100
# 24/24 [==============================] - 0s 883us/step - loss: 0.0291 - accuracy: 1.0000
# Epoch 47/100
# 24/24 [==============================] - 0s 869us/step - loss: 0.0277 - accuracy: 1.0000
# Epoch 48/100
# 24/24 [==============================] - 0s 956us/step - loss: 0.0265 - accuracy: 1.0000
# Epoch 49/100
# 24/24 [==============================] - 0s 994us/step - loss: 0.0253 - accuracy: 1.0000
# Epoch 50/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 51/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 52/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 53/100
# 24/24 [==============================] - 0s 985us/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 54/100
# 24/24 [==============================] - 0s 925us/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 55/100
# 24/24 [==============================] - 0s 982us/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 56/100
# 24/24 [==============================] - 0s 943us/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 57/100
# 24/24 [==============================] - 0s 921us/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 58/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 59/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 60/100
# 24/24 [==============================] - 0s 956us/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 61/100
# 24/24 [==============================] - 0s 915us/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 62/100
# 24/24 [==============================] - 0s 890us/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 63/100
# 24/24 [==============================] - 0s 915us/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 64/100
# 24/24 [==============================] - 0s 895us/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 65/100
# 24/24 [==============================] - 0s 957us/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 66/100
# 24/24 [==============================] - 0s 927us/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 67/100
# 24/24 [==============================] - 0s 930us/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 68/100
# 24/24 [==============================] - 0s 949us/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 69/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 70/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 71/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 72/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 73/100
# 24/24 [==============================] - 0s 985us/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 74/100
# 24/24 [==============================] - 0s 935us/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 75/100
# 24/24 [==============================] - 0s 970us/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 76/100
# 24/24 [==============================] - 0s 921us/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 77/100
# 24/24 [==============================] - 0s 922us/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 78/100
# 24/24 [==============================] - 0s 947us/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 79/100
# 24/24 [==============================] - 0s 854us/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 80/100
# 24/24 [==============================] - 0s 955us/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 81/100
# 24/24 [==============================] - 0s 893us/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 82/100
# 24/24 [==============================] - 0s 940us/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 83/100
# 24/24 [==============================] - 0s 934us/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 84/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 85/100
# 24/24 [==============================] - 0s 958us/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 86/100
# 24/24 [==============================] - 0s 935us/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 87/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 88/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 89/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 90/100
# 24/24 [==============================] - 0s 893us/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 91/100
# 24/24 [==============================] - 0s 920us/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 92/100
# 24/24 [==============================] - 0s 992us/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 93/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 94/100
# 24/24 [==============================] - 0s 855us/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 95/100
# 24/24 [==============================] - 0s 920us/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 96/100
# 24/24 [==============================] - 0s 871us/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 97/100
# 24/24 [==============================] - 0s 922us/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 98/100
# 24/24 [==============================] - 0s 945us/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 99/100
# 24/24 [==============================] - 0s 920us/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 100/100
# 24/24 [==============================] - 0s 900us/step - loss: 0.0046 - accuracy: 1.0000

# %% [markdown]
# ## Plotting Loss and Accuracy

# %%
# Create a DataFrame with the history dictionary
df = pd.DataFrame(model.history, index=range(1, len(model.history["loss"]) + 1))

# %%
# Plot the loss
df.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# Plot the accuracy
df.plot(y="accuracy")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Evaluating the Model Performance

# %%
# Evaluate the model using testing data
model_loss, model_accuracy = neuron.evaluate(X_test_scaled, y_test, verbose=2)

# Display evaluation results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.0040 - accuracy: 1.0000 - 307ms/epoch - 38ms/step
# Loss: 0.004009755793958902, Accuracy: 1.0
