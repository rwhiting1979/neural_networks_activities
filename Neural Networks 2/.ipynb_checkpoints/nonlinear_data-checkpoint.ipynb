# %% [markdown]
# # Instructor Do: Connecting Neurons

# %%
# Initial imports
import pandas as pd
import numpy as np
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %matplotlib inline

# %% [markdown]
# ## Creating Dummy Data

# %%
# Creating dummy non-linear data
X_moons, y_moons = make_moons(n_samples=1000, noise=0.08, random_state=78)

# %%
# Transforming y_moons to a vertical vector
y_moons = y_moons.reshape(-1, 1)

# %%
# Creating a DataFrame to plot the non-linear dummy data
df_moons = pd.DataFrame(X_moons, columns=["Feature 1", "Feature 2"])
df_moons["Target"] = y_moons
df_moons.head()
# Out:
#    Feature 1  Feature 2  Target
# 0   0.676217   0.815220       0
# 1   1.487143  -0.210519       1
# 2  -1.027709   0.354966       0
# 3   0.236012   1.025531       0
# 4   1.856695  -0.042783       1

# %%
# Plotting the non-linear dummy data
df_moons.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
# Out:
# <AxesSubplot:xlabel='Feature 1', ylabel='Feature 2'>

# %% [markdown]
# ## Data Preprocessing

# %%
# Create training and testing sets
X_moon_train, X_moon_test, y_moon_train, y_moon_test = train_test_split(
    X_moons, y_moons, random_state=1
)

# %%
# Create the scaler instance
X_moon_scaler = StandardScaler()

# %%
# Fit the scaler
X_moon_scaler.fit(X_moon_train)
# Out:
# StandardScaler()

# %%
# Scale the data
X_moon_train_scaled = X_moon_scaler.transform(X_moon_train)
X_moon_test_scaled = X_moon_scaler.transform(X_moon_test)

# %% [markdown]
# ## Neural Network Model Creation
#
# ![Simple neural network](../Images/simple-nn.png)

# %%
# Create the sequential model
nn = Sequential()

# %%
# First layer
number_inputs = 2
number_hidden_nodes = 6

nn.add(Dense(units=number_hidden_nodes, activation="relu", input_dim=number_inputs))

# %% [markdown]
# ### Output Layer
#
# ![Output layer](../Images/simple-nn-layer-2.png)

# %%
# Output layer
number_classes = 1

nn.add(Dense(units=number_classes, activation="sigmoid"))

# %%
# Model summary
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 18
#
#  dense_1 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile the Model

# %%
# Compile model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# ## Fit the Model

# %%
# Training the model with the non-linear data
model_moon = nn.fit(X_moon_train_scaled, y_moon_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 0s 969us/step - loss: 0.6702 - accuracy: 0.6400
# Epoch 2/100
# 24/24 [==============================] - 0s 833us/step - loss: 0.6381 - accuracy: 0.6600
# Epoch 3/100
# 24/24 [==============================] - 0s 993us/step - loss: 0.6092 - accuracy: 0.6787
# Epoch 4/100
# 24/24 [==============================] - 0s 850us/step - loss: 0.5826 - accuracy: 0.7067
# Epoch 5/100
# 24/24 [==============================] - 0s 922us/step - loss: 0.5582 - accuracy: 0.7427
# Epoch 6/100
# 24/24 [==============================] - 0s 987us/step - loss: 0.5352 - accuracy: 0.7600
# Epoch 7/100
# 24/24 [==============================] - 0s 913us/step - loss: 0.5138 - accuracy: 0.7733
# Epoch 8/100
# 24/24 [==============================] - 0s 967us/step - loss: 0.4937 - accuracy: 0.7880
# Epoch 9/100
# 24/24 [==============================] - 0s 939us/step - loss: 0.4751 - accuracy: 0.7987
# Epoch 10/100
# 24/24 [==============================] - 0s 868us/step - loss: 0.4578 - accuracy: 0.8027
# Epoch 11/100
# 24/24 [==============================] - 0s 938us/step - loss: 0.4419 - accuracy: 0.8053
# Epoch 12/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4270 - accuracy: 0.8147
# Epoch 13/100
# 24/24 [==============================] - 0s 854us/step - loss: 0.4132 - accuracy: 0.8200
# Epoch 14/100
# 24/24 [==============================] - 0s 851us/step - loss: 0.4003 - accuracy: 0.8293
# Epoch 15/100
# 24/24 [==============================] - 0s 892us/step - loss: 0.3883 - accuracy: 0.8347
# Epoch 16/100
# 24/24 [==============================] - 0s 921us/step - loss: 0.3768 - accuracy: 0.8360
# Epoch 17/100
# 24/24 [==============================] - 0s 856us/step - loss: 0.3665 - accuracy: 0.8440
# Epoch 18/100
# 24/24 [==============================] - 0s 905us/step - loss: 0.3567 - accuracy: 0.8520
# Epoch 19/100
# 24/24 [==============================] - 0s 964us/step - loss: 0.3476 - accuracy: 0.8547
# Epoch 20/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3396 - accuracy: 0.
# Epoch 72/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2457 - accuracy: 0.8827
# Epoch 73/100
# 24/24 [==============================] - 0s 868us/step - loss: 0.2451 - accuracy: 0.8853
# Epoch 74/100
# 24/24 [==============================] - 0s 858us/step - loss: 0.2448 - accuracy: 0.8867
# Epoch 75/100
# 24/24 [==============================] - 0s 964us/step - loss: 0.2441 - accuracy: 0.8880
# Epoch 76/100
# 24/24 [==============================] - 0s 915us/step - loss: 0.2437 - accuracy: 0.8880
# Epoch 77/100
# 24/24 [==============================] - 0s 901us/step - loss: 0.2431 - accuracy: 0.8880
# Epoch 78/100
# 24/24 [==============================] - 0s 903us/step - loss: 0.2426 - accuracy: 0.8880
# Epoch 79/100
# 24/24 [==============================] - 0s 861us/step - loss: 0.2420 - accuracy: 0.8880
# Epoch 80/100
# 24/24 [==============================] - 0s 906us/step - loss: 0.2415 - accuracy: 0.8880
# Epoch 81/100
# 24/24 [==============================] - 0s 799us/step - loss: 0.2410 - accuracy: 0.8893
# Epoch 82/100
# 24/24 [==============================] - 0s 881us/step - loss: 0.2403 - accuracy: 0.8893
# Epoch 83/100
# 24/24 [==============================] - 0s 844us/step - loss: 0.2399 - accuracy: 0.8893
# Epoch 84/100
# 24/24 [==============================] - 0s 969us/step - loss: 0.2392 - accuracy: 0.8880
# Epoch 85/100
# 24/24 [==============================] - 0s 871us/step - loss: 0.2385 - accuracy: 0.8880
# Epoch 86/100
# 24/24 [==============================] - 0s 906us/step - loss: 0.2380 - accuracy: 0.8880
# Epoch 87/100
# 24/24 [==============================] - 0s 816us/step - loss: 0.2374 - accuracy: 0.8893
# Epoch 88/100
# 24/24 [==============================] - 0s 799us/step - loss: 0.2367 - accuracy: 0.8880
# Epoch 89/100
# 24/24 [==============================] - 0s 866us/step - loss: 0.2362 - accuracy: 0.8880
# Epoch 90/100
# 24/24 [==============================] - 0s 810us/step - loss: 0.2356 - accuracy: 0.8893
# Epoch 91/100
# 24/24 [==============================] - 0s 914us/step - loss: 0.2351 - accuracy: 0.8893
# Epoch 92/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2346 - accuracy: 0.8907
# Epoch 93/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2338 - accuracy: 0.8920
# Epoch 94/100
# 24/24 [==============================] - 0s 991us/step - loss: 0.2333 - accuracy: 0.8907
# Epoch 95/100
# 24/24 [==============================] - 0s 976us/step - loss: 0.2326 - accuracy: 0.8907
# Epoch 96/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2320 - accuracy: 0.8920
# Epoch 97/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2314 - accuracy: 0.8920
# Epoch 98/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2308 - accuracy: 0.8920
# Epoch 99/100
# 24/24 [==============================] - 0s 923us/step - loss: 0.2302 - accuracy: 0.8920
# Epoch 100/100
# 24/24 [==============================] - 0s 936us/step - loss: 0.2296 - accuracy: 0.8920

# %% [markdown]
# ## Model Evaluation

# %%
# Evaluate the model using non-linear testing data
model_moon_loss, model_moon_accuracy = nn.evaluate(
    X_moon_test_scaled, y_moon_test, verbose=2
)
print(f"Loss: {model_moon_loss}, Accuracy: {model_moon_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.2360 - accuracy: 0.8880 - 106ms/epoch - 13ms/step
# Loss: 0.235958993434906, Accuracy: 0.8880000114440918
